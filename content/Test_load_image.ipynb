# %%
from PIL import Image
import numpy as np
import matplotlib
from matplotlib.pyplot import *
import ipywidgets as widgets
import cv2

# %%
file = open("ER2NB.jpg", "rb")
image = file.read()
im1 = widgets.Image(
    value=image,
    format='png',
    width=300,
    height=400,
)
display(im1)

# %%
pil_im = Image.open('ER1NB.jpg')
image = np.array(pil_im)
gray()
# plot the image
imshow(image)
axis('off')
show()

# %%
# img1 = cv2.imread("ER2NB.jpg", cv2.IMREAD_GRAYSCALE)
# imshow(img1)
# axis("off")
# show()
