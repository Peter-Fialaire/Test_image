# %%
from PIL import Image
import numpy as np
import matplotlib
from matplotlib.pyplot import *
pil_im = Image.open('ER1NB.jpg')
image = np.array(pil_im)
gray()
# plot the image
imshow(image)
axis('off')
# Out:
# (-0.5, 207.5, 245.5, -0.5)
